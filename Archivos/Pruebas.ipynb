# %%
import pandas as pd

# %%
df = pd.read_spss('matrimonios_2015.sav')

# %%
df.head()
# Out:
#           DEPREG                       MUPREG  MESREG  AÑOREG  AÑOOCU  \
# 0      Guatemala                    Guatemala  Agosto  2015.0  2015.0
# 1  Chimaltenango                Chimaltenango   Julio  2015.0  2015.0
# 2     San Marcos                    Malacatán   Julio  2015.0  2015.0
# 3  Huehuetenango  San Sebastián Huehuetenango   Enero  2015.0  2015.0
# 4   Alta Verapaz             San Pedro Carchá   Enero  2016.0  2015.0
#
#                      CLAUNI    NUNUHO    NUNUMU EDADHOM EDADMUJ  ...  \
# 0  Comunidad de gananciales  Ignorado  Ignorado    34.0    32.0  ...
# 1  Comunidad de gananciales  Ignorado  Ignorado    28.0    29.0  ...
# 2  Comunidad de gananciales       1.0       1.0    30.0    22.0  ...
# 3  Comunidad de gananciales       1.0       1.0    58.0    54.0  ...
# 4  Comunidad de gananciales  Ignorado  Ignorado    31.0    28.0  ...
#
#       NACMUJ         ESCHOM         ESCMUJ  \
# 0  Guatemala  Diversificado  Universitario
# ...

# %%
df.describe()
# Out:
#              AÑOREG   AÑOOCU        DIAOCU
# count  79177.000000  79177.0  79177.000000
# mean    2015.085416   2015.0     16.473016
# std        0.279502      0.0      8.541031
# min     2015.000000   2015.0      1.000000
# 25%     2015.000000   2015.0      9.000000
# 50%     2015.000000   2015.0     17.000000
# 75%     2015.000000   2015.0     24.000000
# max     2016.000000   2015.0     31.000000
