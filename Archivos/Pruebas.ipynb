# %%
import pandas as pd

# %%
df = pd.read_spss('Matrimonios_2009.sav')

# %%
df.head()
# Out:
#           DEPREG        MUPREG   MESREG AÑOREG      CLAUNI EDADHOM EDADMUJ  \
# 0     San Marcos  Comitancillo    Abril   2010  Matrimonio    16.0    14.0
# 1     Retalhuleu    Retalhuleu     Mayo   2009  Matrimonio    16.0    14.0
# 2  Huehuetenango      Chiantla    Enero   2010  Matrimonio    16.0    14.0
# 3         Quiche       Joyabaj   Agosto   2009  Matrimonio    16.0    14.0
# 4         Quiche       Joyabaj  Octubre   2009  Matrimonio    16.0    14.0
#
#      GETHOM    GETMUJ     NACHOM     NACMUJ  \
# 0  Indigena  Indigena  Guatemala  Guatemala
# 1  Ignorado  Ignorado  Guatemala  Guatemala
# 2  Ignorado  Ignorado  Guatemala  Guatemala
# 3  Indigena  Indigena  Guatemala  Guatemala
# 4  Indigena  Indigena  Guatemala  Guatemala
#
#                                               OCUHOM  \
# 0                                           Ignorado
# 1  Agricultores y trabajadores calificados de cul...
# 2  Agricultores y trabajadores calificados de cul...
# ...

# %%
df1 = pd.read_spss('matrimonios_2019.sav')

# %%
df1.head()
# Out:
#           DEPREG                       MUPREG  MESREG  AÑOREG  AÑOOCU  \
# 0      Guatemala                    Guatemala  Agosto  2015.0  2015.0
# 1  Chimaltenango                Chimaltenango   Julio  2015.0  2015.0
# 2     San Marcos                    Malacatán   Julio  2015.0  2015.0
# 3  Huehuetenango  San Sebastián Huehuetenango   Enero  2015.0  2015.0
# 4   Alta Verapaz             San Pedro Carchá   Enero  2016.0  2015.0
#
#                      CLAUNI    NUNUHO    NUNUMU EDADHOM EDADMUJ  ...  \
# 0  Comunidad de gananciales  Ignorado  Ignorado    34.0    32.0  ...
# 1  Comunidad de gananciales  Ignorado  Ignorado    28.0    29.0  ...
# 2  Comunidad de gananciales       1.0       1.0    30.0    22.0  ...
# 3  Comunidad de gananciales       1.0       1.0    58.0    54.0  ...
# 4  Comunidad de gananciales  Ignorado  Ignorado    31.0    28.0  ...
#
#       NACMUJ         ESCHOM         ESCMUJ  \
# 0  Guatemala  Diversificado  Universitario
# ...

# %%
df.columns
# Out:
# Index(['DEPREG', 'MUPREG', 'MESREG', 'AÑOREG', 'CLAUNI', 'EDADHOM', 'EDADMUJ',
#        'GETHOM', 'GETMUJ', 'NACHOM', 'NACMUJ', 'OCUHOM', 'OCUMUJ', 'NUPHON',
#        'NUPMUJ', 'DEPOCU', 'MUPOCU', 'MESOCU', 'AÑOOCU', 'AREAG'],
#       dtype='object')
