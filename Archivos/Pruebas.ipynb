# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Cargar todos los matrimonios

# %%
mat09 = pd.read_spss('Matrimonios_2009.sav')
mat10 = pd.read_spss('Matrimonios_2010.sav')
mat11 = pd.read_spss('Matrimonios_2011.sav')
mat12 = pd.read_spss('Matrimonios_2013.sav')
mat13 = pd.read_spss('Matrimonios_2013.sav')
mat14 = pd.read_spss('Matrimonios_2014.sav')
mat15 = pd.read_spss('matrimonios_2015.sav')
mat16 = pd.read_spss('matrimonios_2016.sav')
mat17 = pd.read_spss('matrimonios_2017.sav')
mat18 = pd.read_spss('matrimonios_2018.sav')
mat19 = pd.read_spss('matrimonios_2019.sav')
mat20 = pd.read_spss('matrimonios_2020.sav')

# %% [markdown]
# ## Cargar todos los divorcios

# %%
div09 = pd.read_spss('Divorcios_2009.sav')
div10 = pd.read_spss('Divorcios_2010.sav')
div11 = pd.read_spss('Divorcios_2011.sav')
div12 = pd.read_spss('Divorcios_2013.sav')
div13 = pd.read_spss('Divorcios_2013.sav')
div14 = pd.read_spss('Divorcios_2014.sav')
div15 = pd.read_spss('divorcios_2015.sav')
div16 = pd.read_spss('divorcios_2016.sav')
div17 = pd.read_spss('divorcios_2017.sav')
div18 = pd.read_spss('divorcios_2018.sav')
div19 = pd.read_spss('divorcios_2019.sav')
div20 = pd.read_spss('divorcios_2020.sav')

# %%
mat09 = mat09.rename(columns={'AREAG': 'areagocu','GETHOM': 'puehom','GETMUJ':'puemuj'})
mat10=mat10.rename(columns={'Areag': 'areagocu','Gethom': 'puehom','Getmuj':'puemuj'})
mat11=mat11.rename(columns={'Areag': 'areagocu','Gethom': 'puehom','Getmuj':'puemuj'})

# %%
div09 = div09.rename(columns={'Gethom': 'PUEHOM','Getmuj':'PUEMUJ','Ocuhom':'CIUOHOM','Ocumuj':'CIUOMUJ'})
div10 = div10.rename(columns={'grethom': 'PUEHOM','gretmuj':'PUEMUJ','ocupahom':'CIUOHOM','ocupamuj':'CIUOMUJ','escohom':'ESCHOM','escomuj':'ESCMUJ'})
div11 = div11.rename(columns={'grethom': 'PUEHOM','gretmuj':'PUEMUJ','ocupahom':'CIUOHOM','ocupamuj':'CIUOMUJ','escohom':'ESCHOM','escomuj':'ESCMUJ'})
div20 = div11.rename(columns={'PPERHOM': 'PUEHOM','PPERMUJ':'PUEMUJ'})

# %% [markdown]
# ## unir los dataframes

# %%
framesDiv = [div09, div10, div11, div12,div13,div14,div15,div16,div17,div18,div19,div20]
framesMat = [mat09, mat10, mat11, mat12,mat13,mat14,mat15,mat16,mat17,mat18,mat19,mat20]

# %%
#lower the name of columns for all dataframes inside this list
#for df in framesDiv:
    #df.columns = df.columns.str.lower()
    
for df in framesDiv:
    column_name = df.columns.values.tolist()
    column_name1 = []
    for name in column_name:
        name = name.lower().replace("ñ", "n")
        column_name1.append(name)
    #df.columns = df.columns.str.lower()
    df.columns = column_name1

# %%
#lower the name of columns for all dataframes inside this list
#for df in framesMat:
    #df.columns = df.columns.str.lower()
    
for df in framesMat:
    column_name = df.columns.values.tolist()
    column_name1 = []
    for name in column_name:
        name = name.lower().replace("ñ", "n")
        column_name1.append(name)
    #df.columns = df.columns.str.lower()
    df.columns = column_name1

# %%
df_matrimonios = pd.concat(framesMat)
df_divorcios = pd.concat(framesDiv)

# %%
df_matrimonios.to_csv('matrimonios.csv',index=False,encoding='utf-8')
df_divorcios.to_csv('divorcios.csv',index=False,encoding='utf-8')

# %%
df_divorcios.tail()
# Out:
#              depreg                mupreg     mesreg  anoreg  diaocu  \
# 4339   Sacatepequez     Antigua Guatemala  Diciembre  2011.0    12.0
# 4340  Suchitepequez           Mazatenango      Julio  2011.0    27.0
# 4341         Solola            Panajachel  Diciembre  2011.0     1.0
# 4342         Solola  Santa Cruz la Laguna      Enero  2012.0     5.0
# 4343         Solola  Santa Cruz la Laguna      Julio  2011.0    18.0
#
#           mesocu  anoocu         depocu                mupocu   edadhom  \
# 4339  Septiembre  2011.0   Sacatepequez     Antigua Guatemala  Ignorado
# 4340        Mayo  2011.0  Suchitepequez           Mazatenango      49.0
# 4341   Diciembre  2011.0         Solola                Sololá  Ignorado
# 4342   Diciembre  2011.0         Solola  Santa Cruz la Laguna      47.0
# 4343     Febrero  2011.0         Solola  Santa Cruz la Laguna      46.0
#
#        edadmuj       puehom       puemuj                     nachom  \
# 4339  Ignorado  No indigena  No indigena                  Guatemala
# 4340  Ignorado  No indigena     Ignorado                  Guatemala
# 4341  Ignorado     Ignorado     Ignorado  Estados Unidos de América
# 4342      49.0  No indigena  No indigena                    Francia
# 4343      48.0  No indigena     Ignorado                    Francia
#
#                          nacmuj  \
# 4339  Estados Unidos de América
# 4340  Estados Unidos de América
# 4341  Estados Unidos de América
# 4342  Estados Unidos de América
# 4343  Estados Unidos de América
#
#                                                 ciuohom  \
# 4339                                           Ignorado
# 4340  Agricultores y trabajadores calificados de cul...
# 4341                                           Ignorado
# 4342  Filósofos, historiadores y especialistas en ci...
# 4343  Filósofos, historiadores y especialistas en ci...
#
#                                                 ciuomuj mever  anover  \
# 4339                                           Ignorado   NaN     NaN
# 4340                              Secretarios (general)   NaN     NaN
# 4341                                           Ignorado   NaN     NaN
# 4342  Especialistas en tratamientos de belleza y afines   NaN     NaN
# 4343  Especialistas en tratamientos de belleza y afines   NaN     NaN
#
#              eschom         escmuj
# 4339       Ignorado       Ignorado
# 4340  Universitario       Ignorado
# 4341       Ignorado        Ninguna
# 4342  Universitario  Universitario
# 4343  Universitario  Universitario

# %%
len(df_divorcios.columns)
# Out:
# 21

# %%
div09.head()
# Out:
#           depreg                 mupreg mesreg anoreg  diaocu   mesocu anoocu  \
# 0      Guatemala              Guatemala   Mayo     10     4.0  Febrero     09
# 1      Guatemala  Santa Catarina Pinula  Marzo     09     4.0    Marzo     09
# 2      Guatemala  Santa Catarina Pinula  Abril     09     4.0    Marzo     09
# 3  Chimaltenango          Chimaltenango  Julio     09     4.0     Mayo     09
# 4      Guatemala                 Petapa  Junio     09     5.0     Mayo     09
#
#       depocu     mupocu   edadhom   edadmuj       puehom       puemuj  \
# 0  Guatemala  Guatemala  Ignorado  Ignorado     ignorado     ignorado
# 1  Guatemala  Guatemala      36.0      26.0     ignorado     ignorado
# 2  Guatemala  Guatemala      36.0      26.0     ignorado     ignorado
# 3  Guatemala  Guatemala  Ignorado      29.0     ignorado     ignorado
# 4  Guatemala  Guatemala      33.0      34.0  no indigena  no indigena
#
#       nachom     nacmuj     ciuohom                                   ciuomuj  \
# 0   Ignorado   Ignorado    Ignorado                                  Ignorado
# 1  Guatemala  Guatemala    Ignorado                                  Ignorado
# 2  Guatemala  Guatemala    Ignorado                                  Ignorado
# 3  Guatemala  Guatemala    Ignorado                                  Ignorado
# 4  Guatemala  Guatemala  Estudiante  Secretarios administrativos y ejecutivos
#
#    mever  anover
# 0  Enero  2000.0
# 1  Marzo  2000.0
# 2  Marzo  2000.0
# 3  Marzo  2000.0
# 4  Abril  2000.0

# %%
div11.head()
# Out:
#            depreg          mupreg     mesreg  añoreg  diaocu      mesocu  \
# 0  Quetzaltenango  Quetzaltenango      Julio  2011.0    21.0     Febrero
# 1       Guatemala       Guatemala     Agosto  2011.0     7.0       Abril
# 2       Guatemala       Guatemala    Octubre  2011.0     5.0  Septiembre
# 3          Izabal  Puerto Barrios     Agosto  2011.0     6.0       Julio
# 4       Guatemala       Guatemala  Noviembre  2011.0    29.0       Julio
#
#    añoocu          depocu          mupocu   edadhom   edadmuj   grethom  \
# 0  2011.0  Quetzaltenango  Quetzaltenango      44.0      14.0  Ignorado
# 1  2011.0       Guatemala       Guatemala  Ignorado  Ignorado  Ignorado
# 2  2011.0       Guatemala       Guatemala  Ignorado  Ignorado  Ignorado
# 3  2011.0          Izabal  Puerto Barrios  Ignorado  Ignorado  Ignorado
# 4  2011.0       Guatemala       Guatemala  Ignorado  Ignorado  Ignorado
#
#     gretmuj     nachom     nacmuj   escohom   escomuj  \
# 0  Ignorado  Guatemala  Guatemala  Ignorado  Ignorado
# 1  Ignorado  Guatemala    Austria  Ignorado  Ignorado
# 2  Ignorado  Guatemala    Bolivia  Ignorado  Ignorado
# 3  Ignorado  Guatemala     Canadá  Ignorado  Ignorado
# 4  Ignorado  Guatemala     Canadá  Ignorado  Ignorado
#
#                             ocupahom                              ocupamuj
# 0              Médicos especialistas                              Ignorado
# 1                 Ingenieros civiles  Especialistas en métodos pedagógicos
# 2                           Abogados                           Periodistas
# 3  Peones de explotaciones agrícolas                              Ignorado
# 4                           Ignorado                              Ignorado
