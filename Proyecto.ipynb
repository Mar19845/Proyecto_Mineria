# %% [markdown]
# ## Universidad del Valle de Guatemala
#
# ### Integrantes
# Juan Manuel Marroquin Alfaro 19845
# Carlos Alberto Raxtúm Ramos 19721
# Jose Abraham Gutierrez Corado 19111
# Walter Danilo Saldaña Salguero 19897
# Javier Alejandro Cotto Argueta 19324
#
# ### Mineria de Datos
# ### Sección 20
# ### 25/02/2022

# %%
import pandas as pd

# %% [markdown]
# ## Divorcios

# %%
divorcios = pd.read_csv('./Archivos/divorcios.csv',low_memory=False)
divorcios
# Out:
#               depreg                 mupreg     mesreg  anoreg  diaocu  \
# 0          Guatemala              Guatemala       Mayo    10.0     4.0
# 1          Guatemala  Santa Catarina Pinula      Marzo     9.0     4.0
# 2          Guatemala  Santa Catarina Pinula      Abril     9.0     4.0
# 3      Chimaltenango          Chimaltenango      Julio     9.0     4.0
# 4          Guatemala                 Petapa      Junio     9.0     5.0
# ...              ...                    ...        ...     ...     ...
# 60621   Sacatepequez      Antigua Guatemala  Diciembre  2011.0    12.0
# 60622  Suchitepequez            Mazatenango      Julio  2011.0    27.0
# 60623         Solola             Panajachel  Diciembre  2011.0     1.0
# 60624         Solola   Santa Cruz la Laguna      Enero  2012.0     5.0
# 60625         Solola   Santa Cruz la Laguna      Julio  2011.0    18.0
#
#            mesocu  anoocu         depocu                mupocu   edadhom  ...  \
# 0         Febrero     9.0      Guatemala             Guatemala  Ignorado  ...
# 1           Marzo     9.0      Guatemala             Guatemala      36.0  ...
# 2           Marzo     9.0      Guatemala             Guatemala      36.0  ...
# 3            Mayo     9.0      Guatemala             Guatemala  Ignorado  ...
# 4            Mayo     9.0      Guatemala             Guatemala      33.0  ...
# ...           ...     ...            ...                   ...       ...  ...
# 60621  Septiembre  2011.0   Sacatepequez     Antigua Guatemala  Ignorado  ...
# 60622        Mayo  2011.0  Suchitepequez           Mazatenango      49.0  ...
# 60623   Diciembre  2011.0         Solola                Sololá  Ignorado  ...
# 60624   Diciembre  2011.0         Solola  Santa Cruz la Laguna      47.0  ...
# 60625     Febrero  2011.0         Solola  Santa Cruz la Laguna      46.0  ...
#
#             puehom       puemuj                     nachom  \
# 0         ignorado     ignorado                   Ignorado
# 1         ignorado     ignorado                  Guatemala
# 2         ignorado     ignorado                  Guatemala
# 3         ignorado     ignorado                  Guatemala
# 4      no indigena  no indigena                  Guatemala
# ...            ...          ...                        ...
# 60621  No indigena  No indigena                  Guatemala
# 60622  No indigena     Ignorado                  Guatemala
# 60623     Ignorado     Ignorado  Estados Unidos de América
# 60624  No indigena  No indigena                    Francia
# 60625  No indigena     Ignorado                    Francia
#
#                           nacmuj  \
# 0                       Ignorado
# 1                      Guatemala
# 2                      Guatemala
# 3                      Guatemala
# 4                      Guatemala
# ...                          ...
# 60621  Estados Unidos de América
# 60622  Estados Unidos de América
# 60623  Estados Unidos de América
# 60624  Estados Unidos de América
# 60625  Estados Unidos de América
#
#                                                  ciuohom  \
# 0                                               Ignorado
# 1                                               Ignorado
# 2                                               Ignorado
# 3                                               Ignorado
# 4                                             Estudiante
# ...                                                  ...
# 60621                                           Ignorado
# 60622  Agricultores y trabajadores calificados de cul...
# 60623                                           Ignorado
# 60624  Filósofos, historiadores y especialistas en ci...
# 60625  Filósofos, historiadores y especialistas en ci...
#
#                                                  ciuomuj  mever  anover  \
# 0                                               Ignorado  Enero  2000.0
# 1                                               Ignorado  Marzo  2000.0
# 2                                               Ignorado  Marzo  2000.0
# 3                                               Ignorado  Marzo  2000.0
# 4               Secretarios administrativos y ejecutivos  Abril  2000.0
# ...                                                  ...    ...     ...
# 60621                                           Ignorado    NaN     NaN
# 60622                              Secretarios (general)    NaN     NaN
# 60623                                           Ignorado    NaN     NaN
# 60624  Especialistas en tratamientos de belleza y afines    NaN     NaN
# 60625  Especialistas en tratamientos de belleza y afines    NaN     NaN
#
#               eschom         escmuj
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 60621       Ignorado       Ignorado
# 60622  Universitario       Ignorado
# 60623       Ignorado        Ninguna
# 60624  Universitario  Universitario
# 60625  Universitario  Universitario
#
# [60626 rows x 21 columns]

# %%
divorcios.isna().any()
# Out:
# depreg     False
# mupreg     False
# mesreg     False
# anoreg     False
# diaocu     False
# mesocu     False
# anoocu      True
# depocu     False
# mupocu     False
# edadhom    False
# edadmuj    False
# puehom     False
# puemuj     False
# nachom      True
# nacmuj      True
# ciuohom    False
# ciuomuj    False
# mever       True
# anover      True
# eschom      True
# escmuj      True
# dtype: bool

# %%
drop_rows = []
for i in range(0, 3006):
    drop_rows.append(i)
    
df3 = divorcios.drop(drop_rows)
# Out:
#               depreg                mupreg     mesreg  anoreg  diaocu  \
# 3006       Guatemala             Guatemala      Marzo  2010.0    16.0
# 3007       Guatemala             Guatemala    Octubre  2010.0    25.0
# 3008       Guatemala             Guatemala     Agosto  2010.0    20.0
# 3009    Alta Verapaz                 Cobán      Marzo  2010.0    28.0
# 3010       Guatemala             Guatemala    Octubre  2010.0    23.0
# ...              ...                   ...        ...     ...     ...
# 60621   Sacatepequez     Antigua Guatemala  Diciembre  2011.0    12.0
# 60622  Suchitepequez           Mazatenango      Julio  2011.0    27.0
# 60623         Solola            Panajachel  Diciembre  2011.0     1.0
# 60624         Solola  Santa Cruz la Laguna      Enero  2012.0     5.0
# 60625         Solola  Santa Cruz la Laguna      Julio  2011.0    18.0
#
#            mesocu  anoocu         depocu                mupocu   edadhom  ...  \
# 3006      Febrero  2010.0      Guatemala             Guatemala      42.0  ...
# 3007       Agosto  2010.0      Guatemala             Guatemala      47.0  ...
# 3008         Mayo  2010.0      Guatemala             Guatemala  Ignorado  ...
# 3009        Enero  2010.0   Alta Verapaz                 Cobán      23.0  ...
# 3010        Junio  2010.0      Guatemala             Guatemala  Ignorado  ...
# ...           ...     ...            ...                   ...       ...  ...
# 60621  Septiembre  2011.0   Sacatepequez     Antigua Guatemala  Ignorado  ...
# 60622        Mayo  2011.0  Suchitepequez           Mazatenango      49.0  ...
# 60623   Diciembre  2011.0         Solola                Sololá  Ignorado  ...
# 60624   Diciembre  2011.0         Solola  Santa Cruz la Laguna      47.0  ...
# 60625     Febrero  2011.0         Solola  Santa Cruz la Laguna      46.0  ...
#
#             puehom       puemuj                     nachom  \
# 3006      Ignorado     Ignorado                  Guatemala
# 3007      Ignorado     Ignorado                  Guatemala
# 3008      Ignorado     Ignorado  Estados Unidos de América
# 3009   No indigena  No indigena                  Guatemala
# 3010      Ignorado     Ignorado                  Guatemala
# ...            ...          ...                        ...
# 60621  No indigena  No indigena                  Guatemala
# 60622  No indigena     Ignorado                  Guatemala
# 60623     Ignorado     Ignorado  Estados Unidos de América
# 60624  No indigena  No indigena                    Francia
# 60625  No indigena     Ignorado                    Francia
#
#                           nacmuj  \
# 3006                   Guatemala
# 3007                   Guatemala
# 3008                      México
# 3009                   Guatemala
# 3010                   Guatemala
# ...                          ...
# 60621  Estados Unidos de América
# 60622  Estados Unidos de América
# 60623  Estados Unidos de América
# 60624  Estados Unidos de América
# 60625  Estados Unidos de América
#
#                                                  ciuohom  \
# 3006                   Diseñadores gráficos y multimedia
# 3007                             Comerciantes de tiendas
# 3008                                          Estudiante
# 3009                                          Estudiante
# 3010     Vendedores no clasificados bajo otros epígrafes
# ...                                                  ...
# 60621                                           Ignorado
# 60622  Agricultores y trabajadores calificados de cul...
# 60623                                           Ignorado
# 60624  Filósofos, historiadores y especialistas en ci...
# 60625  Filósofos, historiadores y especialistas en ci...
#
#                                                  ciuomuj mever anover  \
# 3006   Directores de administración y servicios no cl...   NaN    NaN
# 3007   Directores de administración y servicios no cl...   NaN    NaN
# 3008   Directores de administración y servicios no cl...   NaN    NaN
# 3009             Directores de ventas y comercialización   NaN    NaN
# 3010   Gerentes de sucursales de bancos, de servicios...   NaN    NaN
# ...                                                  ...   ...    ...
# 60621                                           Ignorado   NaN    NaN
# 60622                              Secretarios (general)   NaN    NaN
# 60623                                           Ignorado   NaN    NaN
# 60624  Especialistas en tratamientos de belleza y afines   NaN    NaN
# 60625  Especialistas en tratamientos de belleza y afines   NaN    NaN
#
#               eschom         escmuj
# 3006   Diversificado       Ignorado
# 3007         Ninguna        Ninguna
# 3008        Ignorado       Ignorado
# 3009        Ignorado         Básico
# 3010        Ignorado       Ignorado
# ...              ...            ...
# 60621       Ignorado       Ignorado
# 60622  Universitario       Ignorado
# 60623       Ignorado        Ninguna
# 60624  Universitario  Universitario
# 60625  Universitario  Universitario
#
# [57620 rows x 21 columns]

# %%
df3 = df3.drop(['mever', 'anover'], axis=1)
df3
# Out:
#               depreg                mupreg     mesreg  anoreg  diaocu  \
# 3006       Guatemala             Guatemala      Marzo  2010.0    16.0
# 3007       Guatemala             Guatemala    Octubre  2010.0    25.0
# 3008       Guatemala             Guatemala     Agosto  2010.0    20.0
# 3009    Alta Verapaz                 Cobán      Marzo  2010.0    28.0
# 3010       Guatemala             Guatemala    Octubre  2010.0    23.0
# ...              ...                   ...        ...     ...     ...
# 60621   Sacatepequez     Antigua Guatemala  Diciembre  2011.0    12.0
# 60622  Suchitepequez           Mazatenango      Julio  2011.0    27.0
# 60623         Solola            Panajachel  Diciembre  2011.0     1.0
# 60624         Solola  Santa Cruz la Laguna      Enero  2012.0     5.0
# 60625         Solola  Santa Cruz la Laguna      Julio  2011.0    18.0
#
#            mesocu  anoocu         depocu                mupocu   edadhom  \
# 3006      Febrero  2010.0      Guatemala             Guatemala      42.0
# 3007       Agosto  2010.0      Guatemala             Guatemala      47.0
# 3008         Mayo  2010.0      Guatemala             Guatemala  Ignorado
# 3009        Enero  2010.0   Alta Verapaz                 Cobán      23.0
# 3010        Junio  2010.0      Guatemala             Guatemala  Ignorado
# ...           ...     ...            ...                   ...       ...
# 60621  Septiembre  2011.0   Sacatepequez     Antigua Guatemala  Ignorado
# 60622        Mayo  2011.0  Suchitepequez           Mazatenango      49.0
# 60623   Diciembre  2011.0         Solola                Sololá  Ignorado
# 60624   Diciembre  2011.0         Solola  Santa Cruz la Laguna      47.0
# 60625     Febrero  2011.0         Solola  Santa Cruz la Laguna      46.0
#
#         edadmuj       puehom       puemuj                     nachom  \
# 3006       31.0     Ignorado     Ignorado                  Guatemala
# 3007       36.0     Ignorado     Ignorado                  Guatemala
# 3008   Ignorado     Ignorado     Ignorado  Estados Unidos de América
# 3009       37.0  No indigena  No indigena                  Guatemala
# 3010   Ignorado     Ignorado     Ignorado                  Guatemala
# ...         ...          ...          ...                        ...
# 60621  Ignorado  No indigena  No indigena                  Guatemala
# 60622  Ignorado  No indigena     Ignorado                  Guatemala
# 60623  Ignorado     Ignorado     Ignorado  Estados Unidos de América
# 60624      49.0  No indigena  No indigena                    Francia
# 60625      48.0  No indigena     Ignorado                    Francia
#
#                           nacmuj  \
# 3006                   Guatemala
# 3007                   Guatemala
# 3008                      México
# 3009                   Guatemala
# 3010                   Guatemala
# ...                          ...
# 60621  Estados Unidos de América
# 60622  Estados Unidos de América
# 60623  Estados Unidos de América
# 60624  Estados Unidos de América
# 60625  Estados Unidos de América
#
#                                                  ciuohom  \
# 3006                   Diseñadores gráficos y multimedia
# 3007                             Comerciantes de tiendas
# 3008                                          Estudiante
# 3009                                          Estudiante
# 3010     Vendedores no clasificados bajo otros epígrafes
# ...                                                  ...
# 60621                                           Ignorado
# 60622  Agricultores y trabajadores calificados de cul...
# 60623                                           Ignorado
# 60624  Filósofos, historiadores y especialistas en ci...
# 60625  Filósofos, historiadores y especialistas en ci...
#
#                                                  ciuomuj         eschom  \
# 3006   Directores de administración y servicios no cl...  Diversificado
# 3007   Directores de administración y servicios no cl...        Ninguna
# 3008   Directores de administración y servicios no cl...       Ignorado
# 3009             Directores de ventas y comercialización       Ignorado
# 3010   Gerentes de sucursales de bancos, de servicios...       Ignorado
# ...                                                  ...            ...
# 60621                                           Ignorado       Ignorado
# 60622                              Secretarios (general)  Universitario
# 60623                                           Ignorado       Ignorado
# 60624  Especialistas en tratamientos de belleza y afines  Universitario
# 60625  Especialistas en tratamientos de belleza y afines  Universitario
#
#               escmuj
# 3006        Ignorado
# 3007         Ninguna
# 3008        Ignorado
# 3009          Básico
# 3010        Ignorado
# ...              ...
# 60621       Ignorado
# 60622       Ignorado
# 60623        Ninguna
# 60624  Universitario
# 60625  Universitario
#
# [57620 rows x 19 columns]

# %% [markdown]
# ## Matrimonios

# %%
matrimonios = pd.read_csv('./Archivos/matrimonios.csv',low_memory=False)
matrimonios
# Out:
#                depreg             mupreg     mesreg  añoreg  \
# 0          San Marcos       Comitancillo      Abril  2010.0
# 1          Retalhuleu         Retalhuleu       Mayo  2009.0
# 2       Huehuetenango           Chiantla      Enero  2010.0
# 3              Quiche            Joyabaj     Agosto  2009.0
# 4              Quiche            Joyabaj    Octubre  2009.0
# ...               ...                ...        ...     ...
# 907777   Alta Verapaz   San Pedro Carchá    Octubre  2020.0
# 907778          Petén             Flores     Agosto  2020.0
# 907779          Petén            Dolores  Noviembre  2020.0
# 907780   Sacatepéquez  Antigua Guatemala      Junio  2020.0
# 907781  Suchitepéquez        Mazatenango  Noviembre  2020.0
#
#                           clauni edadhom edadmuj    gethom    getmuj  \
# 0                     Matrimonio    16.0    14.0  Indigena  Indigena
# 1                     Matrimonio    16.0    14.0  Ignorado  Ignorado
# 2                     Matrimonio    16.0    14.0  Ignorado  Ignorado
# 3                     Matrimonio    16.0    14.0  Indigena  Indigena
# 4                     Matrimonio    16.0    14.0  Indigena  Indigena
# ...                          ...     ...     ...       ...       ...
# 907777  Comunidad de gananciales    28.0    18.0       NaN       NaN
# 907778  Comunidad de gananciales    31.0    29.0       NaN       NaN
# 907779  Comunidad de gananciales    33.0    26.0       NaN       NaN
# 907780        Comunidad absoluta    39.0    32.0       NaN       NaN
# 907781  Comunidad de gananciales    37.0    31.0       NaN       NaN
#
#            nachom  ...         eschom         escmuj diaocu            puehom  \
# 0       Guatemala  ...            NaN            NaN    NaN               NaN
# 1       Guatemala  ...            NaN            NaN    NaN               NaN
# 2       Guatemala  ...            NaN            NaN    NaN               NaN
# 3       Guatemala  ...            NaN            NaN    NaN               NaN
# 4       Guatemala  ...            NaN            NaN    NaN               NaN
# ...           ...  ...            ...            ...    ...               ...
# 907777  Guatemala  ...  Diversificado       Ignorado   30.0  Ladino / Mestizo
# 907778  Guatemala  ...  Diversificado       Ignorado   24.0  Ladino / Mestizo
# 907779  Guatemala  ...  Universitario  Diversificado    9.0  Ladino / Mestizo
# 907780  Guatemala  ...  Universitario       Ignorado   14.0  Ladino / Mestizo
# 907781  Guatemala  ...  Universitario       Ignorado   12.0  Ladino / Mestizo
#
#           puemuj                           ciuohom   ciuomuj areagocu  \
# 0            NaN                               NaN       NaN      NaN
# 1            NaN                               NaN       NaN      NaN
# 2            NaN                               NaN       NaN      NaN
# 3            NaN                               NaN       NaN      NaN
# 4            NaN                               NaN       NaN      NaN
# ...          ...                               ...       ...      ...
# 907777  Ignorado     Profesionales de la enseñanza  Ignorado      NaN
# 907778  Ignorado     Profesionales de la enseñanza  Ignorado      NaN
# 907779  Ignorado     Profesionales de la enseñanza  Ignorado      NaN
# 907780  Ignorado  Oficiales de las fuerzas armadas  Ignorado      NaN
# 907781  Ignorado  Oficiales de las fuerzas armadas  Ignorado      NaN
#
#           nunuho    nunumu
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ...          ...       ...
# 907777  Ignorado  Ignorado
# 907778       1.0       1.0
# 907779  Ignorado  Ignorado
# 907780  Ignorado  Ignorado
# 907781  Ignorado  Ignorado
#
# [907782 rows x 30 columns]
